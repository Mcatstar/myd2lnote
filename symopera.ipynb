# %%
import sympy as sp

x, y, z = sp.symbols('x y z')
sp.init_printing()

print(sp.diff(sp.cos(x), x))
expr = sp.exp(x*y*z)
print(sp.diff(expr, x, y, y, z, z, z, z))
# Out:
# -sin(x)
# x**3*y**2*(x**3*y**3*z**3 + 14*x**2*y**2*z**2 + 52*x*y*z + 48)*exp(x*y*z)
